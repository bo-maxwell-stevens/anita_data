# %%
import pandas as pd
import numpy as np
import os
from os.path import isfile, join
import xlrd

# %%
mypath = 'sensor_data'
deca_files = []
for f in os.listdir(mypath):
    if 'Decagon' in f and not f.startswith('_'):
        if 'Jornada' in f or 'Hill' in f:
            deca_files.append(join(mypath,f))

# %%
deca_files
# Out:
# ['sensor_data/Hill Decagon March 2014',
#  'sensor_data/Jornada Decagon March 2014',
#  'sensor_data/Jornada Decagon Sept 26, 2014',
#  'sensor_data/Hill Decagon June 2014']

# %%
def parse_deca_filename(f):
    site = f[0]
    soil_type = f[1]
    #an I in one of the filenames (soil type), converted to 1
    if soil_type == 'I':
        soil_type = 1
    monitor_station = f[2:4]
    replicate = f[5]
    return site, soil_type, monitor_station, replicate

# %%
def parse_deca(f):
    new_df = pd.read_csv(f, skiprows = 3, header = None)
    return new_df

# %%
final_df = pd.DataFrame()
df = pd.DataFrame()
for x in range(len(deca_files)):
    for f in os.listdir(deca_files[x]):
        if 'csv' in f and not f.startswith('.'):
            tmp_df = parse_deca(join(deca_files[x],f))
            tmp_df.columns = ['Date_time','1','2','3','4','5']
            tmp_df.to_csv('tmp.csv')
            tmp_df = pd.read_csv('tmp.csv', index_col = 0, parse_dates = ['Date_time'])
            tmp_df = tmp_df.set_index('Date_time')
            
            df = pd.DataFrame(index = tmp_df.index)
            df['site'], df['soil_type'], df['monitor_station'], df['replicate'] = parse_deca_filename(f)
            
            df1 = df.copy()
            df1['Date_time'] = #insert index
            df1['treatement'] = 'Cr'
            df1['habitat'] = 'C'
            df1['soil_m'] = tmp_df['1']
            df1 = df1[df1['soil_m'].notnull()]
            day_df1 = collapse_by_day(df1)
            
            df2 = df.copy()
            df2['treatement'] = 'C'
            df2['habitat'] = 'P'
            df2['soil_m'] = tmp_df['2']
            
            df3 = df.copy()
            df3['treatement'] = 'H'
            df3['habitat'] = 'C'
            df3['soil_m'] = tmp_df['3']
            
            df4 = df.copy()
            df4['treatement'] = 'H'
            df4['habitat'] = 'S'
            df3['soil_m'] = tmp_df['3']
            final_df = final_df.append(df1, ignore_index = True)
            final_df = final_df.append(df2[df2['Date_time'].notnull()], ignore_index = True)
            final_df = final_df.append(df3[df3['Date_time'].notnull()], ignore_index = True)
            final_df = final_df.append(df4[df4['Date_time'].notnull()], ignore_index = True)
            print join(deca_files[x],f)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-144-348d80d3a3dc> in <module>()
#      35             df3['soil_m'] = tmp_df['3']
#      36             final_df = final_df.append(df1, ignore_index = True)
# ---> 37             final_df = final_df.append(df2[df2['Date_time'].notnull()], ignore_index = True)
#      38             final_df = final_df.append(df3[df3['Date_time'].notnull()], ignore_index = True)
#      39             final_df = final_df.append(df4[df4['Date_time'].notnull()], ignore_index = True)
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1676             return self._getitem_multilevel(key)
#    1677         else:
# -> 1678             return self._getitem_column(key)
#    1679
#    1680     def _getitem_column(self, key):
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1683         # get column
#    1684         if self.columns.is_unique:
# -> 1685             return self._get_item_cache(key)
#    1686
#    1687         # duplicate columns & possible reduce dimensionaility
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1050         res = cache.get(item)
#    1051         if res is None:
# -> 1052             values = self._data.get(item)
#    1053             res = self._box_item_values(item, values)
#    1054             cache[item] = res
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    2563
#    2564             if not isnull(item):
# -> 2565                 loc = self.items.get_loc(item)
#    2566             else:
#    2567                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/core/index.pyc in get_loc(self, key)
#    1179         loc : int if unique index, possibly slice or mask if not
#    1180         """
# -> 1181         return self._engine.get_loc(_values_from_object(key))
#    1182
#    1183     def get_value(self, series, key):
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3354)()
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/index.so in pandas.index.IndexEngine.get_loc (pandas/index.c:3234)()
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11148)()
#
# /home/bonobo/.virtualenvs/pandas/local/lib/python2.7/site-packages/pandas/hashtable.so in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:11101)()
#
# KeyError: 'Date_time'

# %%
final_df = final_df.set_index('Date_time')

# %%
final_df.to_csv('Decagon.csv')

# %%
date_df = pd.read_csv('Decagon.csv', parse_dates = ['Date_time'], index_col = 0)

# %%
date_df[:5]
# Out:
#                     habitat monitor_station  replicate site  soil_m  \
# Date_time
# 2013-10-23 10:00:00       C              M2          1    H   0.237
# 2013-10-23 12:00:00       C              M2          1    H   0.228
# 2013-10-23 14:00:00       C              M2          1    H   0.231
# 2013-10-23 16:00:00       C              M2          1    H   0.233
# 2013-10-23 18:00:00       C              M2          1    H   0.235
#
#                      soil_type treatement
# Date_time
# 2013-10-23 10:00:00          2         Cr
# 2013-10-23 12:00:00          2         Cr
# 2013-10-23 14:00:00          2         Cr
# 2013-10-23 16:00:00          2         Cr
# 2013-10-23 18:00:00          2         Cr

# %%
def collapse_by_day(df):
    new_df = pd.DataFrame()
    new_df['soil_m_mean'] = df.groupby(pd.TimeGrouper('1D'))['soil_m'].mean()
    new_df['soil_m_max'] = df.groupby(pd.TimeGrouper('1D'))['soil_m'].max()
    new_df['soil_m_min'] = df.groupby(pd.TimeGrouper('1D'))['soil_m'].min()
    new_df['soil_m_std'] = df.groupby(pd.TimeGrouper('1D'))['soil_m'].std()
    return new_df

# %%
final_time_df = collapse_by_day(date_df)

# %%
final_time_df
# Out:
#             soil_m_mean  soil_m_max  soil_m_min  soil_m_std
# Date_time
# 2001-06-05     0.329424       0.361       0.301    0.017420
# 2001-06-06     0.327861       0.358       0.299    0.017617
# 2001-06-07     0.325583       0.357       0.297    0.018398
# 2001-06-08     0.319028       0.352       0.289    0.018356
# 2001-06-09     0.314528       0.344       0.283    0.018320
# 2001-06-10     0.312806       0.342       0.279    0.019217
# 2001-06-11     0.308833       0.338       0.273    0.019779
# 2001-06-12     0.304389       0.334       0.267    0.021055
# 2001-06-13     0.303278       0.333       0.264    0.022277
# 2001-06-14     0.299306       0.332       0.257    0.023788
# 2001-06-15     0.294250       0.327       0.245    0.025393
# 2001-06-16     0.289444       0.322       0.240    0.026987
# 2001-06-17     0.286056       0.317       0.233    0.028621
# 2001-06-18     0.282528       0.315       0.230    0.029969
# 2001-06-19     0.277167       0.308       0.220    0.031820
# 2001-06-20     0.273361       0.305       0.216    0.033779
# 2001-06-21     0.271083       0.305       0.212    0.034718
# 2001-06-22     0.266972       0.303       0.206    0.036946
# 2001-06-23     0.265583       0.302       0.204    0.038630
# 2001-06-24     0.259611       0.301       0.194    0.040842
# 2001-06-25     0.255639       0.294       0.191    0.041800
# 2001-06-26     0.253778       0.290       0.190    0.042473
# 2001-06-27     0.250639       0.295       0.178    0.045387
# 2001-06-28     0.251611       0.296       0.188    0.040978
# 2001-06-29     0.257139       0.301       0.192    0.040045
# 2001-06-30     0.259722       0.301       0.193    0.042316
# 2001-07-01     0.238182       0.300      -0.058    0.081684
# 2001-07-02          NaN         NaN         NaN         NaN
# 2001-07-03          NaN         NaN         NaN         NaN
# 2001-07-04          NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...
# 2014-07-08     0.079694       0.153      -0.007    0.045504
# 2014-07-09     0.081458       0.154      -0.011    0.045713
# 2014-07-10     0.094535       0.148       0.016    0.040947
# 2014-07-11     0.094764       0.282       0.012    0.049401
# 2014-07-12     0.169083       0.322       0.058    0.067154
# 2014-07-13     0.198736       0.291       0.082    0.056623
# 2014-07-14     0.185771       0.303       0.074    0.054933
# 2014-07-15     0.170139       0.251       0.073    0.049021
# 2014-07-16     0.158722       0.237       0.067    0.042501
# 2014-07-17     0.151229       0.226       0.084    0.040347
# 2014-07-18     0.131090       0.194       0.066    0.038945
# 2014-07-19     0.116174       0.178       0.051    0.038310
# 2014-07-20     0.103514       0.160       0.039    0.037361
# 2014-07-21     0.094424       0.148       0.031    0.036834
# 2014-07-22     0.087229       0.143       0.024    0.036237
# 2014-07-23     0.089438       0.134       0.030    0.030183
# 2014-07-24     0.080528       0.130       0.019    0.032983
# 2014-07-25     0.075472       0.126       0.012    0.032845
# 2014-07-26     0.069840       0.120       0.003    0.031892
# 2014-07-27     0.067806       0.118      -0.002    0.032304
# 2014-07-28     0.075653       0.174       0.001    0.034761
# 2014-07-29     0.110986       0.180       0.025    0.035748
# 2014-07-30     0.107174       0.153       0.046    0.031288
# 2014-07-31     0.097396       0.142       0.036    0.031059
# 2014-08-01     0.182792       0.357       0.033    0.074226
# 2014-08-02     0.173875       0.279       0.075    0.058136
# 2014-08-03     0.155111       0.252       0.064    0.050516
# 2014-08-04     0.164854       0.234       0.096    0.041203
# 2014-08-05     0.151778       0.236       0.078    0.041165
# 2014-08-06     0.136111       0.213       0.067    0.043077
#
# [4811 rows x 4 columns]

# %%
def parse_butt(f):
    new_df = pd.read_csv(f, skiprows = 20, header = None)
    return new_df

# %%
mypath = 'sensor_data'
butt_files = []
for f in os.listdir(mypath):
    if 'iButton' in f and not f.startswith('_'):
        if 'Jornada' in f or 'Hill' in f:
            butt_files.append(join(mypath,f))

# %%
butt_files
#there's an extra folder, seems like a copy
# Out:
# ['sensor_data/Hill iButton March 2014',
#  'sensor_data/Hill iButton June2014',
#  'sensor_data/Jornada iButton Sept 26, 2014',
#  'sensor_data/Jornada iButton March 2014',
#  'sensor_data/Hill iButton data April_Oct2013']

# %%
def parse_butt_filename(f):
    f = f.split('_')
    print f
    first = f[0]
    second = f[1]
    site = first[0]
    soil_type = first[1]
    #an I in one of the filenames (soil type), converted to 1
    if soil_type == 'I':
        soil_type = 1
    monitor_station = first[-2:]
    treatment = first[2:4]
    habitat = first[4:]
    return site, soil_type, monitor_station, treatment, habitat

# %%
final_df = pd.DataFrame()
df = pd.DataFrame() #columns = ['Date_time','site','soil_type','monitor_station','replicate','treatment','habitat','soil_m']
for x in range(len(butt_files)):
    for f in sorted(os.listdir(butt_files[x])):
        if 'csv' in f and not f.startswith('.'):
            test = f.split('_')
            for f in sorted(os.listdir(butt_files[x])):
                match = f.split('_')
                if test[0] == match[0] and test[1] != match[1]:
                    tmp_df = parse_butt(join(butt_files[x],f))
                    df['Date_time'] = tmp_df[0]
                    df['site'], df['soil_type'], df['monitor_station'], df['treatment'], df['habitat_mod'] = parse_butt_filename(f)
# Out:
# ['H1M1P', 'temp', 'Mar', '2014.csv']
# ['H1M1P', 'RH', 'Mar', '2014.csv']
# ['H1M2HS', 'temp', 'Mar', '2014.csv']
# ['H1M2HS', 'RH', 'Mar', '2014.csv']
# ['H1M2H', 'temp', 'Mar', '2014.csv']
# ['H1M2H', 'RH', 'Mar', '2014.csv']
# ['H1M2P', 'temp', 'Mar', '2014.csv']
# ['H1M2P', 'RH', 'Mar', '2014.csv']
# ['H2M1HS', 'Temp', 'Mar', '2014.csv']
# ['H2M1HS', 'RH', 'Mar', '2014.csv']
# ['H2M1P', 'Temp', 'Mar', '2014.csv']
# ['H2M1P', 'RH', 'Mar', '2014.csv']
# ['H2M2HS', 'Temp', 'Mar', '2014.csv']
# ['H2M2HS', 'RH', 'Mar', '2014.csv']
# ['H2M2H', 'Temp', 'Mar', '2014.csv']
# ['H2M2H', 'RH', 'Mar', '2014.csv']
# ['H2M2P', 'Temp', 'Mar', '2014.csv']
# ['H2M2P', 'RH', 'Mar', '2014.csv']
# ['H1M1HS', 'Temp', 'June2014.csv']
# ['H1M1HS', 'RH', 'June2014.csv']
# ['H1M1P', 'Temp', 'June2014.csv']
# ['H1M1P', 'RH', 'June2014.csv']
# ['H1M2HS', 'Temp', 'June2014.csv']
# ['H1M2HS', 'RH', 'June2014.csv']
# ['H1M2H', 'Temp', 'June2014.csv']
# ['H1M2H', 'RH', 'June2014.csv']
# ['H1M2P', 'Temp', 'June2014.csv']
# ['H1M2P', 'RH', 'June2014.csv']
# ['H2M1H', 'Temp', 'June2014.csv']
# ['H2M1H', 'RH', 'June2014.csv']
# ['H2M2HS', 'Temp', 'June2014.csv']
# ['H2M2HS', 'RH', 'June2014.csv']
# ['J1M1HS', 'Temp', 'Sept2014.csv']
# ['J1M1HS', 'RH', 'Sept2014.csv']
# ['J1M1H', 'Temp', 'Sept2014.csv']
# ['J1M1H', 'RH', 'Sept2014.csv']
# ['J1M2H', 'Temp', 'Sept2014.csv']
# ['J1M2H', 'RH', 'Sept2014.csv']
# ['J1M2P1', 'Temp', 'Sept2014.csv']
# ['J1M2P1', 'RH', 'Sept2014.csv']
# ['J1M2S', 'Temp', 'Sept2014.csv']
# ['J1M2S', 'RH', 'Sept2014.csv']
# ['J2M1H', 'Temp', 'Sept2014.csv']
# ['J2M1H', 'RH', 'Sept2014.csv']
# ['J2M2H', 'Temp', 'Sept2014.csv']
# ['J2M2H', 'RH', 'Sept2014.csv']
# ['J2M2P1', 'Temp', 'Sept2014.csv']
# ['J2M2P1', 'RH', 'Sept2014.csv']
# ['J1M1HS', 'Temp', 'Mar', '2014.csv']
# ['J1M1HS', 'RH', 'Mar', '2014.csv']
# ['J1M1H', 'Temp', 'Mar', '2014.csv']
# ['J1M1H', 'RH', 'Mar', '2014.csv']
# ['J1M1P', 'Temp', 'Mar', '2014.csv']
# ['J1M1P', 'RH', 'Mar', '2014.csv']
# ['J1M2HS', 'Temp', 'Mar', '2014.csv']
# ['J1M2HS', 'RH', 'Mar', '2014.csv']
# ['J1M2H', 'Temp', 'Mar', '2014.csv']
# ['J1M2H', 'RH', 'Mar', '2014.csv']
# ['J1M2P', 'Temp', 'Mar', '2014.csv']
# ['J1M2P', 'RH', 'Mar', '2014.csv']
# ['J2M1HS', 'Temp', 'Mar', '2014.csv']
# ['J2M1HS', 'RH', 'Mar', '2014.csv']
# ['J2M1H', 'Temp', 'Mar', '2014.csv']
# ['J2M1H', 'RH', 'Mar', '2014.csv']
# ['J2M1P', 'Temp', 'Mar', '2014.csv']
# ['J2M1P', 'RH', 'Mar', '2014.csv']
# ['J2M2HS', 'Temp', 'Mar', '2014.csv']
# ['J2M2HS', 'RH', 'Mar', '2014.csv']
# ['J2M2H', 'Temp', 'Mar', '2014.csv']
# ['J2M2H', 'RH', 'Mar', '2014.csv']
# ['J2M2P', 'Temp', 'Mar', '2014.csv']
# ['J2M2P', 'RH', 'Mar', '2014.csv']
# ['H1HM2', 'TEMP.csv']
# ['H1HM2', 'RH.csv']
# ['H1HSM1', 'TEMP.csv']
# ['H1HSM1', 'RH.csv']
# ['H1HSM2', 'TEMP.csv']
# ['H1HSM2', 'RH.csv']
# ['H1P1M1', 'TEMP.csv']
# ['H1P1M1', 'RH.csv']
# ['H1P1M2', 'TEMP.csv']
# ['H1P1M2', 'RH.csv']
# ['H2HM1', 'TEMP.csv']
# ['H2HM1', 'RH.csv']
# ['H2HM2', 'TEMP.csv']
# ['H2HM2', 'RH.csv']
# ['H2HSM1', 'TEMP.csv']
# ['H2HSM1', 'RH.csv']
# ['H2HSM2', 'temp.csv']
# ['H2HSM2', 'RH.csv']
# ['H2P1M1', 'TEMP.csv']
# ['H2P1M1', 'RH.csv']
# ['H2P1M2', 'temp.csv']
# ['H2P1M2', 'rh.csv']

# %%
df
# Out:
#                Date_time site soil_type monitor_station treatment habitat_mod
# 0    4/24/13 12:00:01 AM    H         2              M2        P1          M2
# 1     4/24/13 4:00:01 AM    H         2              M2        P1          M2
# 2     4/24/13 8:00:01 AM    H         2              M2        P1          M2
# 3    4/24/13 12:00:01 PM    H         2              M2        P1          M2
# 4     4/24/13 4:00:01 PM    H         2              M2        P1          M2
# 5     4/24/13 8:00:01 PM    H         2              M2        P1          M2
# 6    4/25/13 12:00:01 AM    H         2              M2        P1          M2
# 7     4/25/13 4:00:01 AM    H         2              M2        P1          M2
# 8     4/25/13 8:00:01 AM    H         2              M2        P1          M2
# 9    4/25/13 12:00:01 PM    H         2              M2        P1          M2
# 10    4/25/13 4:00:01 PM    H         2              M2        P1          M2
# 11    4/25/13 8:00:01 PM    H         2              M2        P1          M2
# 12   4/26/13 12:00:01 AM    H         2              M2        P1          M2
# 13    4/26/13 4:00:01 AM    H         2              M2        P1          M2
# 14    4/26/13 8:00:01 AM    H         2              M2        P1          M2
# 15   4/26/13 12:00:01 PM    H         2              M2        P1          M2
# 16    4/26/13 4:00:01 PM    H         2              M2        P1          M2
# 17    4/26/13 8:00:01 PM    H         2              M2        P1          M2
# 18   4/27/13 12:00:01 AM    H         2              M2        P1          M2
# 19    4/27/13 4:00:01 AM    H         2              M2        P1          M2
# 20    4/27/13 8:00:01 AM    H         2              M2        P1          M2
# 21   4/27/13 12:00:01 PM    H         2              M2        P1          M2
# 22    4/27/13 4:00:01 PM    H         2              M2        P1          M2
# 23    4/27/13 8:00:01 PM    H         2              M2        P1          M2
# 24   4/28/13 12:00:01 AM    H         2              M2        P1          M2
# 25    4/28/13 4:00:01 AM    H         2              M2        P1          M2
# 26    4/28/13 8:00:01 AM    H         2              M2        P1          M2
# 27   4/28/13 12:00:01 PM    H         2              M2        P1          M2
# 28    4/28/13 4:00:01 PM    H         2              M2        P1          M2
# 29    4/28/13 8:00:01 PM    H         2              M2        P1          M2
# ..                   ...  ...       ...             ...       ...         ...
# 852  9/13/13 12:00:01 AM    H         2              M2        P1          M2
# 853   9/13/13 4:00:01 AM    H         2              M2        P1          M2
# 854   9/13/13 8:00:01 AM    H         2              M2        P1          M2
# 855  9/13/13 12:00:01 PM    H         2              M2        P1          M2
# 856   9/13/13 4:00:01 PM    H         2              M2        P1          M2
# 857   9/13/13 8:00:01 PM    H         2              M2        P1          M2
# 858  9/14/13 12:00:01 AM    H         2              M2        P1          M2
# 859   9/14/13 4:00:01 AM    H         2              M2        P1          M2
# 860   9/14/13 8:00:01 AM    H         2              M2        P1          M2
# 861  9/14/13 12:00:01 PM    H         2              M2        P1          M2
# 862   9/14/13 4:00:01 PM    H         2              M2        P1          M2
# 863   9/14/13 8:00:01 PM    H         2              M2        P1          M2
# 864  9/15/13 12:00:01 AM    H         2              M2        P1          M2
# 865   9/15/13 4:00:01 AM    H         2              M2        P1          M2
# 866   9/15/13 8:00:01 AM    H         2              M2        P1          M2
# 867  9/15/13 12:00:01 PM    H         2              M2        P1          M2
# 868   9/15/13 4:00:01 PM    H         2              M2        P1          M2
# 869   9/15/13 8:00:01 PM    H         2              M2        P1          M2
# 870  9/16/13 12:00:01 AM    H         2              M2        P1          M2
# 871   9/16/13 4:00:01 AM    H         2              M2        P1          M2
# 872   9/16/13 8:00:01 AM    H         2              M2        P1          M2
# 873  9/16/13 12:00:01 PM    H         2              M2        P1          M2
# 874   9/16/13 4:00:01 PM    H         2              M2        P1          M2
# 875   9/16/13 8:00:01 PM    H         2              M2        P1          M2
# 876  9/17/13 12:00:01 AM    H         2              M2        P1          M2
# 877   9/17/13 4:00:01 AM    H         2              M2        P1          M2
# 878   9/17/13 8:00:01 AM    H         2              M2        P1          M2
# 879  9/17/13 12:00:01 PM    H         2              M2        P1          M2
# 880   9/17/13 4:00:01 PM    H         2              M2        P1          M2
# 881   9/17/13 8:00:01 PM    H         2              M2        P1          M2
#
# [882 rows x 6 columns]

# %%
final_df.to_csv('iButton.csv')

# %%
final_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
