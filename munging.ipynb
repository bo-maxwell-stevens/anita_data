# %%
import pandas as pd
import numpy as np
from os import listdir
from os.path import isfile, join

# %%
# !ls 'sensor_data/Hill iButton data April_Oct2013'
# Out:
# H1HM2_RH.csv	 H1P1M2_RH.csv	  H2HSM2_RH.csv
# H1HM2_TEMP.csv	 H1P1M2_TEMP.csv  H2HSM2_temp.csv
# H1HSM1_RH.csv	 H2HM1_RH.csv	  H2P1M1_RH.csv
# H1HSM1_TEMP.csv  H2HM1_TEMP.csv   H2P1M1_TEMP.csv
# H1HSM2_RH.csv	 H2HM2_RH.csv	  H2P1M2_rh.csv
# H1HSM2_TEMP.csv  H2HM2_TEMP.csv   H2P1M2_temp.csv
# H1P1M1_RH.csv	 H2HSM1_RH.csv	  HilliButtonforJMP.xlsx
# H1P1M1_TEMP.csv  H2HSM1_TEMP.csv  HilliButton MasterOct24_13.xlsx

# %%
mypath ='sensor_data/Hill iButton data April_Oct2013'
files = [ f for f in listdir(mypath) if isfile(join(mypath,f)) ]

# %%
files
# Out:
# ['H2HSM2_temp.csv',
#  'H2P1M1_RH.csv',
#  'H2P1M1_TEMP.csv',
#  'H2HM1_RH.csv',
#  'H2HSM2_RH.csv',
#  'H1HSM1_RH.csv',
#  'H2P1M2_rh.csv',
#  'H1HSM1_TEMP.csv',
#  'H2HM2_RH.csv',
#  'H2P1M2_temp.csv',
#  'H1HM2_RH.csv',
#  'H1P1M2_TEMP.csv',
#  'H2HM1_TEMP.csv',
#  'H1P1M1_TEMP.csv',
#  'H1HM2_TEMP.csv',
#  'H1P1M2_RH.csv',
#  'H2HSM1_RH.csv',
#  'H1HSM2_RH.csv',
#  'H1HSM2_TEMP.csv',
#  'HilliButton MasterOct24_13.xlsx',
#  'H2HSM1_TEMP.csv',
#  'HilliButtonforJMP.xlsx',
#  'H1P1M1_RH.csv',
#  'H2HM2_TEMP.csv']

# %%
# !head -n 21 'sensor_data/Hill iButton data April_Oct2013/H2HSM2_temp.csv'
# Out:
# 1-Wire/iButton Part Number: DS1923
# 1-Wire/iButton Registration Number: 1100000029982141
# Mission in Progress?  true
# SUTA Mission?  false
# Waiting for Temperature Alarm?  false
# Sample Rate:  Every 14400 second(s)
# Mission Start Time:  Wed Apr 24 00:00:01 MDT 2013
# Mission Sample Count:  1097
# Roll Over Enabled?  false(no rollover occurred)
# First Sample Timestamp:  Wed Apr 24 00:00:01 MDT 2013
# Total Mission Samples:  1097
# Total Device Samples:  7664
# Temperature Logging:  0.5 C
# Temperature High Alarm:  disabled
# Temperature Low Alarm:  disabled
# Data Logging:  0.6 %RH
# Data High Alarm:  disabled
# Data Low Alarm:  disabled
#
# Date/Time,Unit,Value
# 4/24/13 12:00:01 AM,C,23.086

# %%
for file in range(len(files[1])):
    df = pd.read_csv(join(mypath,files[file]), skiprows = 19, header = 0, index_col = 0)

# %%
df
# Out:
#                      Unit   Value
# Date/Time
# 4/24/13 7:00:01 AM      C  23.601
# 4/24/13 11:00:01 AM     C  11.081
# 4/24/13 3:00:01 PM      C  28.101
# 4/24/13 7:00:01 PM      C  12.084
# 4/24/13 11:00:01 PM     C   4.558
# 4/25/13 3:00:01 AM      C   2.047
# 4/25/13 7:00:01 AM      C   1.545
# 4/25/13 11:00:01 AM     C  27.101
# 4/25/13 3:00:01 PM      C  25.102
# 4/25/13 7:00:01 PM      C  14.590
# 4/25/13 11:00:01 PM     C   8.071
# 4/26/13 3:00:01 AM      C   5.060
# 4/26/13 7:00:01 AM      C   4.558
# 4/26/13 11:00:01 AM     C  29.600
# 4/26/13 3:00:01 PM      C  35.093
# 4/26/13 7:00:01 PM      C  17.595
# 4/26/13 11:00:01 PM     C  11.081
# 4/27/13 3:00:01 AM      C   7.068
# 4/27/13 7:00:01 AM      C   7.570
# 4/27/13 11:00:01 AM     C  33.096
# 4/27/13 3:00:01 PM      C  38.086
# 4/27/13 7:00:01 PM      C  20.599
# 4/27/13 11:00:01 PM     C  13.587
# 4/28/13 3:00:01 AM      C  10.579
# 4/28/13 7:00:01 AM      C   9.075
# 4/28/13 11:00:01 AM     C  30.100
# ...
