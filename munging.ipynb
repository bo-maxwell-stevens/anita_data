# %%
import pandas as pd
import numpy as np
import os
from os.path import isfile, join
import xlrd

# %%
# !ls 'sensor_data'
# Out:
# Data_Output_Format.xlsx		   Hill Oct 24, 2013
# Decagon data April_Oct 2013	   iButton data April_Oct2013
# __HillDecagon data April_Oct 2013  Jornada Decagon March 2014
# Hill Decagon June 2014		   Jornada Decagon Sept 26, 2014
# Hill Decagon March 2014		   Jornada iButton March 2014
# Hill iButton data April_Oct2013    Jornada iButton Sept 26, 2014
# Hill iButton June2014		   __MACOSX
# Hill iButton March 2014		   Metadata for sensor data.docx

# %%
mypath = 'sensor_data'
deca_files = []
for f in os.listdir(mypath):
    if 'Decagon' in f and not f.startswith('_'):
        if 'Jornada' in f or 'Hill' in f:
            deca_files.append(join(mypath,f))

# %%
def parse_deca_filename(f):
    site = f[0]
    soil_type = f[1]
    #an I in one of the filenames (soil type), converted to 1
    if soil_type == 'I':
        soil_type = 1
    monitor_station = f[2:4]
    replicate = f[5]
    return site, soil_type, monitor_station, replicate

# %%
def parse_deca(f):
    new_df = pd.read_csv(f, skiprows = 3, skip_blank_lines=True, header = None)
    return new_df

# %%
deca_files
# Out:
# ['sensor_data/Jornada Decagon Sept 26, 2014',
#  'sensor_data/Hill Decagon June 2014',
#  'sensor_data/Hill Decagon March 2014',
#  'sensor_data/Jornada Decagon March 2014']

# %%
final_df = pd.DataFrame()
df = pd.DataFrame() #columns = ['Date_time','site','soil_type','monitor_station','replicate','treatment','habitat','soil_m']
for x in range(len(deca_files)):
    for f in os.listdir(deca_files[x]):
        if 'csv' in f and not f.startswith('.'):
            tmp_df = parse_deca(join(deca_files[x],f))
            df['Date_time'] = tmp_df[0]
            df['site'], df['soil_type'], df['monitor_station'], df['replicate'] = parse_deca_filename(f)
            df1 = df.copy()
            df1['treatement'] = 'Cr'
            df1['habitat'] = 'C'
            df1['soil_m'] = tmp_df[1]
            df2 = df.copy()
            df2['treatement'] = 'C'
            df2['habitat'] = 'P'
            df2['soil_m'] = tmp_df[2]
            df3 = df.copy()
            df3['treatement'] = 'H'
            df3['habitat'] = 'C'
            df3['soil_m'] = tmp_df[3]
            df4 = df.copy()
            df4['treatement'] = 'H'
            df4['habitat'] = 'S'
            df3['soil_m'] = tmp_df[3]
            final_df = final_df.append(df1[df1['Date_time'].notnull()], ignore_index = True)
            final_df = final_df.append(df2[df2['Date_time'].notnull()], ignore_index = True)
            final_df = final_df.append(df3[df3['Date_time'].notnull()], ignore_index = True)
            final_df = final_df.append(df4[df4['Date_time'].notnull()], ignore_index = True)
            print join(deca_files[x],f)
# Out:
# sensor_data/Jornada Decagon Sept 26, 2014/J2M2_26Sep14-2026.csv
# sensor_data/Jornada Decagon Sept 26, 2014/J1M1_26Sep14-1926.csv
# sensor_data/Jornada Decagon Sept 26, 2014/J1M2_26Sep14-1957.csv
# sensor_data/Jornada Decagon Sept 26, 2014/J2M1_26Sep14-2017.csv
# sensor_data/Hill Decagon June 2014/H2M2_1_21Jun14-1802.csv
# sensor_data/Hill Decagon June 2014/H2M1_2_21Jun14-1804.csv
# 134718    3/9/2014 6:00 AM       S              M2         1    J     NaN
# 134719    3/9/2014 8:00 AM       S              M2         1    J     NaN
# 134720   3/9/2014 10:00 AM       S              M2         1    J     NaN
# 134721   3/9/2014 12:00 PM       S              M2         1    J     NaN
# 134722    3/9/2014 2:00 PM       S              M2         1    J     NaN
# 134723    3/9/2014 4:00 PM       S              M2         1    J     NaN
# 134724    3/9/2014 6:00 PM       S              M2         1    J     NaN
# 134725    3/9/2014 8:00 PM       S              M2         1    J     NaN
# 134726   3/9/2014 10:00 PM       S              M2         1    J     NaN
# 134727  3/10/2014 12:00 AM       S              M2         1    J     NaN
# 134728   3/10/2014 2:00 AM       S              M2         1    J     NaN
# 134729   3/10/2014 4:00 AM       S              M2         1    J     NaN
# 134730   3/10/2014 6:00 AM       S              M2         1    J     NaN
# 134731   3/10/2014 8:00 AM       S              M2         1    J     NaN
# 134732  3/10/2014 10:00 AM       S              M2         1    J     NaN
# 134733  3/10/2014 12:00 PM       S              M2         1    J     NaN
# 134734   3/10/2014 2:00 PM       S              M2         1    J     NaN
# 134735   3/10/2014 4:00 PM       S              M2         1    J     NaN
# 134736   3/10/2014 6:00 PM       S              M2         1    J     NaN
# 134737   3/10/2014 8:00 PM       S              M2         1    J     NaN
# 134738  3/10/2014 10:00 PM       S              M2         1    J     NaN
# 134739  3/11/2014 12:00 AM       S              M2         1    J     NaN
# 134740   3/11/2014 2:00 AM       S              M2         1    J     NaN
# 134741   3/11/2014 4:00 AM       S              M2         1    J     NaN
# 134742   3/11/2014 6:00 AM       S              M2         1    J     NaN
# 134743   3/11/2014 8:00 AM       S              M2         1    J     NaN
# 134744  3/11/2014 10:00 AM       S              M2         1    J     NaN
# 134745  3/11/2014 12:00 PM       S              M2         1    J     NaN
# 134746   3/11/2014 2:00 PM       S              M2         1    J     NaN
# 134747   3/11/2014 4:00 PM       S              M2         1    J     NaN
#
#        soil_type treatement
# 0              2         Cr
# 1              2         Cr
# 2              2         Cr
# 3              2         Cr
# 4              2         Cr
# 5              2         Cr
# 6              2         Cr
# 7              2         Cr
# 8              2         Cr
# 9              2         Cr
# 10             2         Cr
# 11             2         Cr
# 12             2         Cr
# 13             2         Cr
# 14             2         Cr
# 15             2         Cr
# 16             2         Cr
# 17             2         Cr
# 18             2         Cr
# 19             2         Cr
# 20             2         Cr
# 21             2         Cr
# 22             2         Cr
# 23             2         Cr
# 24             2         Cr
# 25             2         Cr
# 26             2         Cr
# 27             2         Cr
# 28             2         Cr
# 29             2         Cr
# ...          ...        ...
# 134718         2          H
# 134719         2          H
# 134720         2          H
# 134721         2          H
# 134722         2          H
# 134723         2          H
# 134724         2          H
# 134725         2          H
# 134726         2          H
# 134727         2          H
# 134728         2          H
# 134729         2          H
# 134730         2          H
# 134731         2          H
# 134732         2          H
# 134733         2          H
# 134734         2          H
# 134735         2          H
# 134736         2          H
# 134737         2          H
# 134738         2          H
# 134739         2          H
# 134740         2          H
# 134741         2          H
# 134742         2          H
# 134743         2          H
# 134744         2          H
# 134745         2          H
# 134746         2          H
# 134747         2          H
#
# [134748 rows x 8 columns]
